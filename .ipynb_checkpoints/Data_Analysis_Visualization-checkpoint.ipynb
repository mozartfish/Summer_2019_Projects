# %%
import pandas as pd

# %%
df = pd.read_csv('../Summer_2019_Projects/avocado.csv')

df = df.copy()[df['type'] == "organic"]
df['Date'] = pd.to_datetime(df["Date"])

df.sort_values(by = "Date", ascending = True, inplace = True)

# %%
albany_df = df[df['region']=="Albany"]
albany_df.set_index("Date", inplace=True)

albany_df["AveragePrice"].plot()

# %%
# apply moving average (at every point compute the average and roll the average)
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
#albany_df.head(25)
#albany_df.index
albany_df.sort_index(inplace = True)
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()
# Out:
# c:\users\pranav\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df.head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046    4225  4770  \
# Date
# 2015-01-04          51          1.79       1373.95  57.42  153.88   0.0
# 2015-01-11          50          1.77       1182.56  39.00  305.12   0.0
# 2015-01-18          49          1.93       1118.47   8.02  178.78   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-01-04     1162.65     1162.65         0.0          0.0  organic  2015
# 2015-01-11      838.44      838.44         0.0          0.0  organic  2015
# 2015-01-18      931.67      931.67         0.0          0.0  organic  2015
#
#             region  price25ma
# Date
# 2015-01-04  Albany        NaN
# 2015-01-11  Albany        NaN
# 2015-01-18  Albany        NaN

# %%
albany_df.tail(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume    4046    4225  4770  \
# Date
# 2018-03-11           2          1.68       2570.52  131.67  229.56   0.0
# 2018-03-18           1          1.66       3154.45  275.89  297.96   0.0
# 2018-03-25           0          1.71       2321.82   42.95  272.41   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-03-11     2209.29     2209.29        0.00          0.0  organic  2018
# 2018-03-18     2580.60     2577.27        3.33          0.0  organic  2018
# 2018-03-25     2006.46     1996.46       10.00          0.0  organic  2018
#
#             region  price25ma
# Date
# 2018-03-11  Albany     1.5044
# 2018-03-18  Albany     1.5140
# 2018-03-25  Albany     1.5188

# %%
# removes any rows that have NA's values (cleans the data to make it easier to analyze)
albany_df.dropna().head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046    4225  4770  \
# Date
# 2015-06-21          27          2.09       1053.73  17.59  107.87   0.0
# 2015-06-28          26          2.02       1200.61  22.35  124.70   0.0
# 2015-07-05          25          2.04       1573.19  50.69  183.90   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-06-21      928.27      928.27         0.0          0.0  organic  2015
# 2015-06-28     1053.56     1053.56         0.0          0.0  organic  2015
# 2015-07-05     1338.60     1338.60         0.0          0.0  organic  2015
#
#             region  price25ma
# Date
# 2015-06-21  Albany     1.8748
# 2015-06-28  Albany     1.8840
# 2015-07-05  Albany     1.8948

# %%
# tell warning that you are referencing the main data frame and making a copy
albany_df = df.copy()[df["region"] == "Albany"]
albany_df.set_index("Date", inplace=True)
albany_df.sort_index(inplace = True)
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()

# %%
# graph of all the features (in the case of avocado this is the regions)
# we use a multi-dimensional array
df.values
# Out:
# array([[51, Timestamp('2015-01-04 00:00:00'), 1.24, ..., 'organic', 2015,
#         'California'],
#        [51, Timestamp('2015-01-04 00:00:00'), 1.5, ..., 'organic', 2015,
#         'LasVegas'],
#        [51, Timestamp('2015-01-04 00:00:00'), 1.12, ..., 'organic', 2015,
#         'PhoenixTucson'],
#        ...,
#        [0, Timestamp('2018-03-25 00:00:00'), 1.33, ..., 'organic', 2018,
#         'BaltimoreWashington'],
#        [0, Timestamp('2018-03-25 00:00:00'), 1.74, ..., 'organic', 2018,
#         'LosAngeles'],
#        [0, Timestamp('2018-03-25 00:00:00'), 1.58, ..., 'organic', 2018,
#         'Northeast']], dtype=object)

# %%
# too many values
#df['region'].values.tolist()
# hacky code
#list(set(df['region'].values.tolist()))
df['region'].unique()
# Out:
# array(['California', 'LasVegas', 'PhoenixTucson', 'BuffaloRochester',
#        'Spokane', 'LosAngeles', 'Philadelphia', 'Boston', 'StLouis',
#        'Louisville', 'Orlando', 'Southeast', 'Boise', 'MiamiFtLauderdale',
#        'NorthernNewEngland', 'BaltimoreWashington', 'Midsouth', 'Tampa',
#        'West', 'Northeast', 'Atlanta', 'Nashville', 'TotalUS', 'Syracuse',
#        'WestTexNewMexico', 'Jacksonville', 'Charlotte', 'Sacramento',
#        'GrandRapids', 'Roanoke', 'Denver', 'SanDiego', 'GreatLakes',
#        'RichmondNorfolk', 'DallasFtWorth', 'SanFrancisco',
#        'HarrisburgScranton', 'Pittsburgh', 'RaleighGreensboro', 'Seattle',
#        'HartfordSpringfield', 'Portland', 'CincinnatiDayton',
#        'SouthCarolina', 'Houston', 'Chicago', 'Plains', 'Indianapolis',
#        'SouthCentral', 'Columbus', 'Albany', 'Detroit',
#        'NewOrleansMobile', 'NewYork'], dtype=object)

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    print(region)
    region_df = df.copy()[df['region'] == region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace = True)
    region_df[f'{region}_price25ma'] = region_df['AveragePrice'].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
        
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma']) # bring data frames together on an index
        
    graph_df.tail()
# code is slow because it explodes RAM
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
# Midsouth
# Tampa
# West
# Northeast
# Atlanta
# Nashville
# TotalUS
# Syracuse
# WestTexNewMexico
# Jacksonville
# Charlotte
# Sacramento
# GrandRapids
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco
# HarrisburgScranton
# Pittsburgh
# RaleighGreensboro
# Seattle
# HartfordSpringfield
# Portland
# CincinnatiDayton
# SouthCarolina
# Houston
# Chicago
# Plains
# Indianapolis
# SouthCentral
# Columbus
# Albany
# Detroit
# NewOrleansMobile
# NewYork

# %%
df['type'].unique() # we have two types of data
graph_df.tail() # many identical indexes
# RAM is exploding because of the date field
# Out:
#             California_price25ma  LasVegas_price25ma  PhoenixTucson_price25ma  \
# Date
# 2018-02-25                1.9128              1.9120                   1.7468
# 2018-03-04                1.8876              1.8748                   1.7404
# 2018-03-11                1.8636              1.8440                   1.7324
# 2018-03-18                1.8516              1.8204                   1.7216
# 2018-03-25                1.8364              1.7968                   1.7104
#
#             BuffaloRochester_price25ma  Spokane_price25ma  \
# Date
# 2018-02-25                      1.2912             2.1544
# 2018-03-04                      1.2744             2.1040
# 2018-03-11                      1.2652             2.0552
# 2018-03-18                      1.2560             2.0012
# 2018-03-25                      1.2416             1.9496
#
#             LosAngeles_price25ma  Philadelphia_price25ma  Boston_price25ma  \
# Date
# ...

# %%
graph_df.dropna().plot(figsize = (8, 5), legend = False)
